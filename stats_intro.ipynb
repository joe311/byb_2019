# %%
import numpy as np
import scipy

# %matplotlib notebook

from matplotlib import pyplot as plt, gridspec
import seaborn.apionly as sns
# Out:
# C:\Users\joe\AppData\Local\Continuum\anaconda3\envs\py37\lib\site-packages\matplotlib\__init__.py:855: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))
# C:\Users\joe\AppData\Local\Continuum\anaconda3\envs\py37\lib\site-packages\matplotlib\__init__.py:846: MatplotlibDeprecationWarning:
# The text.latex.unicode rcparam was deprecated in Matplotlib 2.2 and will be removed in 3.1.
#   "2.2", name=key, obj_type="rcparam", addendum=addendum)
# C:\Users\joe\AppData\Local\Continuum\anaconda3\envs\py37\lib\site-packages\seaborn\apionly.py:9: UserWarning: As seaborn no longer sets a default style on import, the seaborn.apionly module is deprecated. It will be removed in a future version.
#   warnings.warn(msg, UserWarning)

# %%
npoints = 100
scale = .2
means = np.random.normal(loc=0, scale=scale, size=(npoints,100000)).mean(axis=0)
means = means*np.sqrt(npoints)/scale
means.shape
# Out:
# (100000,)

# %%
plt.figure()
plt.hist(means, 100);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#The sampled and analytically calculated distributions are close
plt.figure()
sns.kdeplot(means, label='sampled mean distribution', lw=3)

x = np.linspace(-5, 5, 1000)
plt.plot(x, scipy.stats.t.pdf(x, df=npoints), 'k--', label='true t-dist', alpha=.5)
plt.legend(loc='upper right')
# Out:
# <img src="data:image/png;base64,..." width="640">
