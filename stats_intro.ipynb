# %%
import numpy as np
import scipy

# %matplotlib notebook

from matplotlib import pyplot as plt, gridspec

# %%
npoints = 100
scale = .2
means = np.random.normal(loc=0, scale=scale, size=(npoints,100000)).mean(axis=0)
means = means*np.sqrt(npoints)/scale
means.shape
# Out:
# (100000,)

# %%
plt.figure()
plt.hist(means, 100)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 4.000e+00, 4.000e+00,
#         9.000e+00, 1.100e+01, 1.100e+01, 1.700e+01, 2.100e+01, 2.300e+01,
#         4.000e+01, 5.500e+01, 6.900e+01, 9.200e+01, 1.090e+02, 1.440e+02,
#         1.760e+02, 2.430e+02, 2.970e+02, 4.020e+02, 4.510e+02, 5.230e+02,
#         6.620e+02, 7.610e+02, 8.950e+02, 1.098e+03, 1.254e+03, 1.469e+03,
#         1.657e+03, 1.839e+03, 2.077e+03, 2.354e+03, 2.526e+03, 2.734e+03,
#         2.869e+03, 3.147e+03, 3.250e+03, 3.579e+03, 3.616e+03, 3.593e+03,
#         3.693e+03, 3.676e+03, 3.768e+03, 3.765e+03, 3.678e+03, 3.636e+03,
#         3.468e+03, 3.308e+03, 3.208e+03, 3.073e+03, 2.816e+03, 2.562e+03,
#         2.289e+03, 2.172e+03, 1.868e+03, 1.754e+03, 1.475e+03, 1.316e+03,
#         1.141e+03, 8.690e+02, 8.130e+02, 6.810e+02, 6.060e+02, 4.920e+02,
# ...
